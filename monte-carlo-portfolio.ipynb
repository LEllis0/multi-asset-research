# %%
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tickers = ['AZN', 'GSK', 'HSBA', 'BP', 'SHEL', 'BARC', 'LSEG', 'RIO', 'BATS', 'REL', 'DGE']
tickers = [ticker + '.L' for ticker in tickers]

endDate = dt.datetime.now()
startDate = endDate - dt.timedelta(15*365)

# %%
def equityData(tickers, startDate, endDate):
    returnsData = yf.download(tickers,start=startDate,end=endDate,interval='1d')
    returnsData = returnsData['Adj Close']
    returnsData = returnsData.pct_change()
    meanReturn = returnsData.mean()
    covMatrix = returnsData.cov()
    return returnsData, meanReturn, covMatrix

# %%
returnsData, meanReturn, covMatrix = equityData(tickers,startDate,endDate)
returnsData = returnsData.dropna()
portfolioWeight = [1/len(tickers)]*len(tickers)
# Out:
# [*********************100%***********************]  11 of 11 completed
# /var/folders/33/_ft973790qv2wpzyrpc3p2fr0000gn/T/ipykernel_85348/1879367010.py:4: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   returnsData = returnsData.pct_change()

# %%
returnsData
# Out:
# Ticker                        AZN.L    BARC.L    BATS.L      BP.L     DGE.L  \
# Date
# 2009-10-22 00:00:00+00:00  0.003272 -0.016303 -0.008807 -0.013962 -0.013232
# 2009-10-23 00:00:00+00:00  0.003625  0.006824  0.002793  0.000000 -0.007220
# 2009-10-26 00:00:00+00:00  0.002347 -0.024485  0.002278  0.003717 -0.006753
# 2009-10-27 00:00:00+00:00  0.019636 -0.036302  0.005557  0.048140  0.003138
# 2009-10-28 00:00:00+00:00 -0.014488 -0.061212 -0.016830 -0.016824  0.010949
# ...                             ...       ...       ...       ...       ...
# 2024-10-10 00:00:00+00:00  0.001191  0.002168 -0.001848  0.010950 -0.004112
# 2024-10-11 00:00:00+00:00 -0.000510  0.020333 -0.008519 -0.003408  0.003343
# 2024-10-14 00:00:00+00:00  0.014621 -0.012508  0.008218 -0.002564  0.003331
# 2024-10-15 00:00:00+00:00 -0.007205  0.004938  0.002223 -0.038932  0.007617
# 2024-10-17 00:00:00+00:00  0.010633  0.030335  0.013309  0.018321  0.012987
#
# ...

# %%
portfolioWeight
# Out:
# [0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091,
#  0.09090909090909091]

# %%
meanReturn
# Out:
# Ticker
# AZN.L     0.000648
# BARC.L    0.000287
# BATS.L    0.000398
# BP.L      0.000280
# DGE.L     0.000444
# GSK.L     0.000354
# HSBA.L    0.000305
# LSEG.L    0.000870
# REL.L     0.000730
# RIO.L     0.000524
# SHEL.L    0.000425
# dtype: float64

# %%
returnsData['Portfolio change'] = returnsData.dot(portfolioWeight)
returnsData
# Out:
# /var/folders/33/_ft973790qv2wpzyrpc3p2fr0000gn/T/ipykernel_85348/3393001380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   returnsData['Portfolio change'] = returnsData.dot(portfolioWeight)
# Ticker                        AZN.L    BARC.L    BATS.L      BP.L     DGE.L  \
# Date
# 2009-10-22 00:00:00+00:00  0.003272 -0.016303 -0.008807 -0.013962 -0.013232
# 2009-10-23 00:00:00+00:00  0.003625  0.006824  0.002793  0.000000 -0.007220
# 2009-10-26 00:00:00+00:00  0.002347 -0.024485  0.002278  0.003717 -0.006753
# 2009-10-27 00:00:00+00:00  0.019636 -0.036302  0.005557  0.048140  0.003138
# 2009-10-28 00:00:00+00:00 -0.014488 -0.061212 -0.016830 -0.016824  0.010949
# ...
